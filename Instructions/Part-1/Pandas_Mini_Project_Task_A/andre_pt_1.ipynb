# %% [markdown]
# **BIG BIG HINT! Look in the instructions to guide you on this task.**

# %%
# Dependencies
import pandas as pd
import os
import csv

# %%
# load CSV
file= os.path.join("Resources/2016-FCC-New-Coders-Survey-Data.csv")

# %%
# Read with pandas
new_coders_df=pd.read_csv(file, encoding='iso-8859-1', low_memory=False)

# %%
# Inspect all columns
new_coders_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_coders_df=new_coders_df.iloc[:,[0,1,2,3,4,7,8,9,10,11,29,30,32,36,37,45,48,56,110,111]]
reduced_coders_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million                NaN  United States of America
# 1  between 100,000 and 1 million                NaN  United States of America
# 2            more than 1 million                NaN  United States of America
# 3            more than 1 million                NaN  United States of America
# 4  between 100,000 and 1 million                NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#    HasChildren  HoursLearning   Income            JobRoleInterest  \
# 0          0.0           30.0  32000.0                        NaN
# 1          NaN           30.0  15000.0    Front-End Web Developer
# 2          NaN           20.0  48000.0                        NaN
# 3          NaN           20.0  43000.0    Front-End Web Developer
# 4          NaN           25.0   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
reduced_coders_df= reduced_coders_df.replace({0.0:"No",1.0:"Yes"})
reduced_coders_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# 1  between 100,000 and 1 million               NaN  United States of America
# 2            more than 1 million               NaN  United States of America
# 3            more than 1 million               NaN  United States of America
# 4  between 100,000 and 1 million               NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#   HasChildren HoursLearning   Income            JobRoleInterest  \
# 0          No            30  32000.0                        NaN
# 1         NaN            30  15000.0    Front-End Web Developer
# 2         NaN            20  48000.0                        NaN
# 3         NaN            20  43000.0    Front-End Web Developer
# 4         NaN            25   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
# Calculate total number of respondents in survey
total_surveyed=len(reduced_coders_df)
total_surveyed
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_bootcamp=reduced_coders_df.loc[reduced_coders_df["AttendedBootcamp"]=="Yes"]

# %%
# Calculate average age of attendees

average_age=attended_bootcamp["Age"].mean()


# Calculate how many people attended a bootcamp
number_of_attendees=attended_bootcamp["AttendedBootcamp"].count()

# Calculate how many attendees hold degrees

holds_degree=attended_bootcamp["SchoolDegree"].count()

# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
total_gender=attended_bootcamp["Gender"].count()
male=attended_bootcamp["Gender"].value_counts()['male']
female=attended_bootcamp["Gender"].value_counts()['female']
non_specific= total_gender-male-female

# Calculate percentage of respondents who attended a bootcamp

attended_bootcamp_percentage=(number_of_attendees/total_surveyed)*100

# Calculate percentage of respondents belonging to each gender
male_percent=(male/total_surveyed)*100
female_percent=(female/total_surveyed)*100
non_specific_percent=(non_specific/total_surveyed)*100

# Calculate percentage of attendees with a school degree

holds_degree_percent=(holds_degree/number_of_attendees)*100

# Calculate average post-bootcamp salary
avg_salary=attended_bootcamp["BootcampPostSalary"].mean()

# %%
# Create a new table consolodating above calculations
summary_table=pd.DataFrame({"Total Surveyed":[total_surveyed],
                                           "Total Bootcamp Attendees":[number_of_attendees],
                                           "Percent Attended a Bootcamp":[attended_bootcamp_percentage],
                                           "Average Age":[average_age],
                                           "% Male":[male_percent],
                                           "% Female":[female_percent],
                                           "% Non Gender Specific":[non_specific_percent],
                                           "% with a degree":[holds_degree_percent],
                                           "Average Post Bootcamp Salary":[avg_salary]})

summary_table=summary_table[["Total Surveyed", "Total Bootcamp Attendees", "Average Age", "% Male", "% Female", "% Non Gender Specific","% with a degree","Average Post Bootcamp Salary"]]
summary_table=summary_table.round(2)
summary_table
# Out:
#    Total Surveyed  Total Bootcamp Attendees  Average Age  % Male  % Female  \
# 0           15620                       953        31.07    3.18      2.09
#
#    % Non Gender Specific  % with a degree  Average Post Bootcamp Salary
# 0                   0.07             87.3                      63740.51

# %%
# Improve formatting before outputting spreadsheet

summary_table["% Male"]=summary_table["% Male"].map("{0:,.2f}%".format)
summary_table["% Female"]=summary_table["% Female"].map("{0:,.2f}%".format)
summary_table["Percent Attended a Bootcamp"] = summary_table["Percent Attended a Bootcamp"].map("{0:,.2f}%".format)
summary_table["% Non Gender Specific"] = summary_table["% Non Gender Specific"].map("{0:,.2f}%".format)
summary_table["% with a degree"]= summary_table["% with a degree"].map("{0:,.2f}%".format)
summary_table["Average Post Bootcamp Salary"]= summary_table["Average Post Bootcamp Salary"].map("${0:,0f}".format)
summary_table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Percent Attended a Bootcamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c08848521d90> in <module>
#       3 summary_table["% Male"]=summary_table["% Male"].map("{0:,.2f}%".format)
#       4 summary_table["% Female"]=summary_table["% Female"].map("{0:,.2f}%".format)
# ----> 5 summary_table["Percent Attended a Bootcamp"] = summary_table["Percent Attended a Bootcamp"].map("{0:,.2f}%".format)
#       6 summary_table["% Non Gender Specific"] = summary_table["% Non Gender Specific"].map("{0:,.2f}%".format)
#       7 summary_table["% with a degree"]= summary_table["% with a degree"].map("{0:,.2f}%".format)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Percent Attended a Bootcamp'

# %%
# Export to Excel

summary_table.to_excel("bootcamppart1.xlsx", index=False)
